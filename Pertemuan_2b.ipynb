# %% [markdown]
# <a href="https://colab.research.google.com/github/Calon-raja-ngoding/PCVK_Ganjil_2026/blob/main/Pertemuan_2b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from  skimage import transform
from PIL import Image
import matplotlib.pylab as plt

urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
        "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
        "https://berita.pesisirselatankab.go.id/asset/foto_berita/newsCover_2023_7_27_1690442617847-p3oo3l.jpeg"]

image = io.imread(urls[2])
image = cv.resize(image, (0,0), fx=0.5, fy=0.5)
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
image_3[528:828, 128:428] = [255,255,255]
final_frame = cv.hconcat((image_2,image_3))
cv2_imshow(final_frame)

#membuat garis dengan panjang tertentu
# for y in range (300):
#   image_3[int((tinggi)/2),y + 128] = [255,255,255]
# final_frame = cv.hconcat((image_2,image_3))
# cv2_imshow(final_frame)

#garis silang
# for x in range (lebar):
#   i = int(x * tinggi / lebar)
#   image_3[i,  x] = [255,255,255]
# for x in range (lebar):
#   i = int(tinggi - 1 - x * tinggi / lebar)
#   image_3[i,  x] = [255,255,255]
# final_frame = cv.hconcat((image_2,image_3))
# cv2_imshow(final_frame)

#garis vertikal
# for x in range (tinggi):
#   image_3[x, int((lebar)/2)] = [255,255,255]
# final_frame = cv.hconcat((image_2,image_3))
# cv2_imshow(final_frame)

#garis horizontal
# for y in range (lebar):
#   image_3[int((tinggi)/2),y] = [255,255,255]
# final_frame = cv.hconcat((image_2,image_3))
# cv2_imshow(final_frame)

#ubah rgb ke bgr
# for url in urls:
#   image = io.imread(url)
#   image = cv.resize(image, (0,0), fx=0.5, fy=0.5)
#   image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
#   final_frame = cv.hconcat((image, image_2))
#   cv2_imshow(final_frame)
#   print('\n')

#tampilkan ukuran
# tinggi = image_2.shape[0]
# lebar = image_2.shape[1]
# print("resolusi image: tinggi x lebar = ",tinggi," x ",lebar)
# cv2_imshow(image_2)

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io

url = "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg"
image = io.imread(url)

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io

url = "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg"
image = io.imread(url)

cv.rectangle(image, pt1=(460,130), pt2=(630,300), color=(0,255,0), thickness=3)
cv.circle(image, center=(545,215), radius=85, color=(255,0,0), thickness=8)
# Out:
# array([[[187, 185, 173],
#         [ 98,  69,  65],
#         [ 68,  35,  28],
#         ...,
#         [ 95,  28,  20],
#         [ 93,  28,  22],
#         [ 93,  28,  22]],
#
#        [[171, 167, 158],
#         [ 85,  54,  51],
#         [ 60,  27,  20],
#         ...,
#         [ 94,  23,  17],
#         [ 93,  24,  19],
#         [ 94,  25,  20]],
#
#        [[160, 156, 147],
#         [ 76,  45,  43],
#         [ 57,  22,  18],
#         ...,
#         [ 94,  21,  15],
#         [ 94,  20,  17],
#         [ 92,  21,  17]],
#
#        ...,
#
#        [[159, 133, 134],
#         [153, 129, 127],
#         [153, 133, 126],
#         ...,
#         [ 85,  26,  18],
#         [ 84,  27,  18],
#         [ 82,  28,  18]],
#
#        [[159, 134, 129],
#         [150, 125, 118],
#         [149, 127, 114],
#         ...,
#         [ 90,  29,  28],
#         [ 88,  30,  28],
#         [ 88,  30,  28]],
#
#        [[169, 142, 131],
#         [153, 127, 112],
#         [149, 126, 108],
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2 as cv

black_img = np.zeros(shape=(512,512,3), dtype=np.int16)
cv.rectangle(black_img, pt1=(384,0), pt2=(510,128), color=(0,255,0), thickness=3)
cv.rectangle(black_img, pt1=(200,200), pt2=(300,300), color=(0,0,255), thickness=15)
cv.circle(black_img, center=(100,100), radius=50, color=(255,0,0), thickness=8)
cv.line(black_img, pt1=(0,0), pt2=(512,512), color=(255,255,255), thickness=5)
font= cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img, text='Hello', org=(10,500), fontFace=font, fontScale=4, color=(255,255,0), thickness=2, lineType=cv.LINE_AA)

black_img2 = np.zeros(shape=(512,512,3), dtype=np.int32)
# vertices = np.array([[100,300],[200,200],[400,300],[200,400]], dtype=np.int32)
# vertices
# pts = vertices.reshape((-1,1,2))
# pts
# cv.polylines(black_img2, [pts], isClosed=True, color=(255,0,0), thickness=5)
plt.imshow(black_img2)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

img = cv.imread("/content/contoh .png")
imgRGB = cv.cvtColor(img, cv.COLOR_BGR2RGB)
imgRGBsmall = cv.resize(imgRGB,(400,250))
imgBalik = cv.flip(imgRGBsmall, 1)

fig=plt.figure(figsize=(10,10))
ax=fig.add_subplot(111)
ax.imshow(imgBalik)

# img_gray = cv.imread("/content/contoh .png", cv.IMREAD_GRAYSCALE)
# plt.subplot(1,2,1)
# plt.imshow(img_gray)
# plt.title("Tanpa cmap")
# plt.subplot(1,2,2)
# plt.imshow(img_gray, cmap="gray")
# plt.title("Dengan cmap")
# plt.show()

# img = cv.imread("/content/contoh .png")
# img_gray = cv.imread("/content/contoh .png")
# plt.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB))
# plt.show()

# %%
import cv2 as cv
import matplotlib.pyplot as plt

image = cv.imread("/content/contoh .png")

redBlue = image.copy()
redBlue[:,:,1] = 0
plt.subplot(1,2,1)
plt.imshow(redBlue)
plt.title("Red-Blue")

greenBlue = image.copy()
greenBlue[:,:,0] = 0
plt.subplot(1,2,2)
plt.imshow(greenBlue)
plt.title("Green-Blue")

plt.show()

# %%
import cv2 as cv
import matplotlib.pyplot as plt

image = cv.imread("/content/contoh .png")
image_2 = image[20:115,25:120,:]

plt.imshow(image_2)

# %%
import cv2 as cv
import matplotlib.pyplot as plt

image = cv.imread("/content/contoh .png")
image_2 = image[5:30,:,:]
image_2[:,:,1] = 0
image_2[:,:,2] = 0

plt.imshow(image_2)

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2 as cv
import random as rn
from google.colab.patches import cv2_imshow

sisi1 = rn.randint(100,200)
kotak1 = np.zeros(shape=(sisi1,sisi1,3), dtype=np.int16)
kotak1[:,:] = [rn.randint(0,255),rn.randint(0,255),rn.randint(0,255)]

sisi2 = rn.randint(200,300)
kotak2 = np.zeros(shape=(sisi2,sisi2,3), dtype=np.int16)
kotak2[:,:] = [rn.randint(0,255),rn.randint(0,255),rn.randint(0,255)]

sisi3 = rn.randint(300,400)
kotak3 = np.zeros(shape=(sisi3,sisi3,3), dtype=np.int16)
kotak3[:,:] = [rn.randint(0,255),rn.randint(0,255),rn.randint(0,255)]

sisi4 = rn.randint(400,500)
kotak4 = np.zeros(shape=(sisi4,sisi4,3), dtype=np.int16)
kotak4[:,:] = [rn.randint(0,255),rn.randint(0,255),rn.randint(0,255)]

sisi5 = rn.randint(500,600)
kotak5 = np.zeros(shape=(sisi5,sisi5,3), dtype=np.int16)
kotak5[:,:] = [rn.randint(0,255),rn.randint(0,255),rn.randint(0,255)]

hasil = [kotak1,kotak2,kotak3,kotak4,kotak5]
for kotak in hasil:
  cv2_imshow(kotak)
  print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=173x173>
# <PIL.Image.Image image mode=RGB size=217x217>
# <PIL.Image.Image image mode=RGB size=320x320>
# <PIL.Image.Image image mode=RGB size=404x404>
# <PIL.Image.Image image mode=RGB size=515x515>

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow

image = cv.imread("/content/contoh .png")
balik = cv.flip(image, 0)
cv2_imshow(balik)
# Out:
# <PIL.Image.Image image mode=RGB size=343x542>
